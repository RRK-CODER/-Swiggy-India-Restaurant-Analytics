# %% [markdown]
# <div style="padding: 20px;border-radius: 16px;background-color: #FF3CAC;
# background-image: linear-gradient(225deg, #FF3CAC 0%, #784BA0 50%, #2B86C5 100%);
# color: white;text-align:center;font-family: Inter,sans-serif;">
#         <h4 style="font-size: 24px;">Swiggy Restaurants Dataset</h4>
#     </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/kaggle/input/swiggy-restaurants-dataset/swiggy_file.csv')

# %%
df
# Out:
#                      Restaurant Name                Cuisine Rating  \
# 0                    La Pino'Z Pizza         Pizzas, Pastas    4.0
# 1                    The Second Wife   Indian, North Indian    3.6
# 2                        Tasty Bites     Italian, Beverages    3.8
# 3                        Food Studio        Pizzas, Burgers    3.5
# 4                       Roll Express      Fast Food, Snacks    4.3
# ...                              ...                    ...    ...
# 140652             Yummy Momo'S Cafe     Chinese, Fast Food    4.6
# 140653              CAFE FIRST FLOOR      Beverages, Snacks    3.2
# 140654  Cafe Coffee Aani Barach Kahi                 Snacks    3.2
# 140655       Patil Family Restaurant  North Indian, Biryani    4.3
# 140656      Prabhakar Mama Cha Dhaba           North Indian     --
#
#        Number of Ratings Average Price  Number of Offers  \
# 0            10+ ratings  ₹250 for two                 2
# 1            50+ ratings  ₹250 for two                 2
# 2            10+ ratings  ₹200 for two                 1
# 3              8 ratings   ₹49 for two                 5
# 4           100+ ratings  ₹200 for two                 2
# ...                  ...           ...               ...
# 140652         3 ratings  ₹100 for two                 3
# 140653         3 ratings  ₹200 for two                 2
# 140654       50+ ratings  ₹150 for two                 2
# 140655         9 ratings  ₹200 for two                 2
# 140656   Too Few Ratings  ₹350 for two                 2
#
#                                                Offer Name  \
# 0       FLAT DEAL\nFLAT ₹125 OFF\nUSE FLAT125ABOVE ₹69...
# 1       30% OFF UPTO ₹75\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 2                    FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500
# 3       50% OFF UPTO ₹100\nUSE TRYNEWABOVE ₹129, FLAT ...
# 4       DEAL OF DAY\n10% OFF UPTO ₹40\nUSE STEALDEALAB...
# ...                                                   ...
# 140652  20% OFF UPTO ₹50\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 140653  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140654  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140655  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140656  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
#
#                           Area Pure Veg  Location
# 0       LALA LAJPAT RAI MARKET       No    Abohar
# 1               Central Abohar       No    Abohar
# 2               Central Abohar      Yes    Abohar
# 3               Central Abohar      Yes    Abohar
# 4                Circular Road       No    Abohar
# ...                        ...      ...       ...
# 140652       Yavatmal Locality      Yes  Yavatmal
# 140653           Yavatmal City      Yes  Yavatmal
# 140654       Yavatmal Locality      Yes  Yavatmal
# 140655       Yavatmal Locality       No  Yavatmal
# 140656       Yavatmal Locality       No  Yavatmal
#
# [140657 rows x 10 columns]

# %% [markdown]
# <div style="padding: 20px;border-radius: 16px;background-color: #FF3CAC;
# background-image: linear-gradient(225deg, #FF3CAC 0%, #784BA0 50%, #2B86C5 100%);
# color: white;text-align:center;font-family: Inter,sans-serif;">
#         <h4 style="font-size: 24px;">Data Cleaning</h4>
#     </div>

# %%
#The average price is replaced from 'â‚¹50 for one' to 50
df['Average Price'] = df['Average Price'].str.extract('(\d+)').fillna(0).astype(int)

# %%
df
# Out:
#                      Restaurant Name                Cuisine Rating  \
# 0                    La Pino'Z Pizza         Pizzas, Pastas    4.0
# 1                    The Second Wife   Indian, North Indian    3.6
# 2                        Tasty Bites     Italian, Beverages    3.8
# 3                        Food Studio        Pizzas, Burgers    3.5
# 4                       Roll Express      Fast Food, Snacks    4.3
# ...                              ...                    ...    ...
# 140652             Yummy Momo'S Cafe     Chinese, Fast Food    4.6
# 140653              CAFE FIRST FLOOR      Beverages, Snacks    3.2
# 140654  Cafe Coffee Aani Barach Kahi                 Snacks    3.2
# 140655       Patil Family Restaurant  North Indian, Biryani    4.3
# 140656      Prabhakar Mama Cha Dhaba           North Indian     --
#
#        Number of Ratings  Average Price  Number of Offers  \
# 0            10+ ratings            250                 2
# 1            50+ ratings            250                 2
# 2            10+ ratings            200                 1
# 3              8 ratings             49                 5
# 4           100+ ratings            200                 2
# ...                  ...            ...               ...
# 140652         3 ratings            100                 3
# 140653         3 ratings            200                 2
# 140654       50+ ratings            150                 2
# 140655         9 ratings            200                 2
# 140656   Too Few Ratings            350                 2
#
#                                                Offer Name  \
# 0       FLAT DEAL\nFLAT ₹125 OFF\nUSE FLAT125ABOVE ₹69...
# 1       30% OFF UPTO ₹75\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 2                    FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500
# 3       50% OFF UPTO ₹100\nUSE TRYNEWABOVE ₹129, FLAT ...
# 4       DEAL OF DAY\n10% OFF UPTO ₹40\nUSE STEALDEALAB...
# ...                                                   ...
# 140652  20% OFF UPTO ₹50\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 140653  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140654  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140655  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140656  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
#
#                           Area Pure Veg  Location
# 0       LALA LAJPAT RAI MARKET       No    Abohar
# 1               Central Abohar       No    Abohar
# 2               Central Abohar      Yes    Abohar
# 3               Central Abohar      Yes    Abohar
# 4                Circular Road       No    Abohar
# ...                        ...      ...       ...
# 140652       Yavatmal Locality      Yes  Yavatmal
# 140653           Yavatmal City      Yes  Yavatmal
# 140654       Yavatmal Locality      Yes  Yavatmal
# 140655       Yavatmal Locality       No  Yavatmal
# 140656       Yavatmal Locality       No  Yavatmal
#
# [140657 rows x 10 columns]

# %%
#The restaurants with rating '-' is replaced with zero 
df['Rating'] = df['Rating'].replace('-', '0')

# %%
#The restaurants with rating '-' is replaced with zero 
df['Number of Ratings'] = df['Number of Ratings'].replace('Too Few Ratings', '0')

# %%
df
# Out:
#                      Restaurant Name                Cuisine Rating  \
# 0                    La Pino'Z Pizza         Pizzas, Pastas    4.0
# 1                    The Second Wife   Indian, North Indian    3.6
# 2                        Tasty Bites     Italian, Beverages    3.8
# 3                        Food Studio        Pizzas, Burgers    3.5
# 4                       Roll Express      Fast Food, Snacks    4.3
# ...                              ...                    ...    ...
# 140652             Yummy Momo'S Cafe     Chinese, Fast Food    4.6
# 140653              CAFE FIRST FLOOR      Beverages, Snacks    3.2
# 140654  Cafe Coffee Aani Barach Kahi                 Snacks    3.2
# 140655       Patil Family Restaurant  North Indian, Biryani    4.3
# 140656      Prabhakar Mama Cha Dhaba           North Indian     --
#
#        Number of Ratings  Average Price  Number of Offers  \
# 0            10+ ratings            250                 2
# 1            50+ ratings            250                 2
# 2            10+ ratings            200                 1
# 3              8 ratings             49                 5
# 4           100+ ratings            200                 2
# ...                  ...            ...               ...
# 140652         3 ratings            100                 3
# 140653         3 ratings            200                 2
# 140654       50+ ratings            150                 2
# 140655         9 ratings            200                 2
# 140656                 0            350                 2
#
#                                                Offer Name  \
# 0       FLAT DEAL\nFLAT ₹125 OFF\nUSE FLAT125ABOVE ₹69...
# 1       30% OFF UPTO ₹75\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 2                    FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500
# 3       50% OFF UPTO ₹100\nUSE TRYNEWABOVE ₹129, FLAT ...
# 4       DEAL OF DAY\n10% OFF UPTO ₹40\nUSE STEALDEALAB...
# ...                                                   ...
# 140652  20% OFF UPTO ₹50\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 140653  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140654  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140655  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140656  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
#
#                           Area Pure Veg  Location
# 0       LALA LAJPAT RAI MARKET       No    Abohar
# 1               Central Abohar       No    Abohar
# 2               Central Abohar      Yes    Abohar
# 3               Central Abohar      Yes    Abohar
# 4                Circular Road       No    Abohar
# ...                        ...      ...       ...
# 140652       Yavatmal Locality      Yes  Yavatmal
# 140653           Yavatmal City      Yes  Yavatmal
# 140654       Yavatmal Locality      Yes  Yavatmal
# 140655       Yavatmal Locality       No  Yavatmal
# 140656       Yavatmal Locality       No  Yavatmal
#
# [140657 rows x 10 columns]

# %%
df['Number of Ratings'] = df['Number of Ratings'].str.replace(r'\+.*', '', regex=True)

# %%
df
# Out:
#                      Restaurant Name                Cuisine Rating  \
# 0                    La Pino'Z Pizza         Pizzas, Pastas    4.0
# 1                    The Second Wife   Indian, North Indian    3.6
# 2                        Tasty Bites     Italian, Beverages    3.8
# 3                        Food Studio        Pizzas, Burgers    3.5
# 4                       Roll Express      Fast Food, Snacks    4.3
# ...                              ...                    ...    ...
# 140652             Yummy Momo'S Cafe     Chinese, Fast Food    4.6
# 140653              CAFE FIRST FLOOR      Beverages, Snacks    3.2
# 140654  Cafe Coffee Aani Barach Kahi                 Snacks    3.2
# 140655       Patil Family Restaurant  North Indian, Biryani    4.3
# 140656      Prabhakar Mama Cha Dhaba           North Indian     --
#
#        Number of Ratings  Average Price  Number of Offers  \
# 0                     10            250                 2
# 1                     50            250                 2
# 2                     10            200                 1
# 3              8 ratings             49                 5
# 4                    100            200                 2
# ...                  ...            ...               ...
# 140652         3 ratings            100                 3
# 140653         3 ratings            200                 2
# 140654                50            150                 2
# 140655         9 ratings            200                 2
# 140656                 0            350                 2
#
#                                                Offer Name  \
# 0       FLAT DEAL\nFLAT ₹125 OFF\nUSE FLAT125ABOVE ₹69...
# 1       30% OFF UPTO ₹75\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 2                    FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500
# 3       50% OFF UPTO ₹100\nUSE TRYNEWABOVE ₹129, FLAT ...
# 4       DEAL OF DAY\n10% OFF UPTO ₹40\nUSE STEALDEALAB...
# ...                                                   ...
# 140652  20% OFF UPTO ₹50\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 140653  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140654  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140655  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140656  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
#
#                           Area Pure Veg  Location
# 0       LALA LAJPAT RAI MARKET       No    Abohar
# 1               Central Abohar       No    Abohar
# 2               Central Abohar      Yes    Abohar
# 3               Central Abohar      Yes    Abohar
# 4                Circular Road       No    Abohar
# ...                        ...      ...       ...
# 140652       Yavatmal Locality      Yes  Yavatmal
# 140653           Yavatmal City      Yes  Yavatmal
# 140654       Yavatmal Locality      Yes  Yavatmal
# 140655       Yavatmal Locality       No  Yavatmal
# 140656       Yavatmal Locality       No  Yavatmal
#
# [140657 rows x 10 columns]

# %%
df['Number of Ratings'] = df['Number of Ratings'].str.replace(r'\D', '', regex=True)

# %%
df
# Out:
#                      Restaurant Name                Cuisine Rating  \
# 0                    La Pino'Z Pizza         Pizzas, Pastas    4.0
# 1                    The Second Wife   Indian, North Indian    3.6
# 2                        Tasty Bites     Italian, Beverages    3.8
# 3                        Food Studio        Pizzas, Burgers    3.5
# 4                       Roll Express      Fast Food, Snacks    4.3
# ...                              ...                    ...    ...
# 140652             Yummy Momo'S Cafe     Chinese, Fast Food    4.6
# 140653              CAFE FIRST FLOOR      Beverages, Snacks    3.2
# 140654  Cafe Coffee Aani Barach Kahi                 Snacks    3.2
# 140655       Patil Family Restaurant  North Indian, Biryani    4.3
# 140656      Prabhakar Mama Cha Dhaba           North Indian     --
#
#        Number of Ratings  Average Price  Number of Offers  \
# 0                     10            250                 2
# 1                     50            250                 2
# 2                     10            200                 1
# 3                      8             49                 5
# 4                    100            200                 2
# ...                  ...            ...               ...
# 140652                 3            100                 3
# 140653                 3            200                 2
# 140654                50            150                 2
# 140655                 9            200                 2
# 140656                 0            350                 2
#
#                                                Offer Name  \
# 0       FLAT DEAL\nFLAT ₹125 OFF\nUSE FLAT125ABOVE ₹69...
# 1       30% OFF UPTO ₹75\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 2                    FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500
# 3       50% OFF UPTO ₹100\nUSE TRYNEWABOVE ₹129, FLAT ...
# 4       DEAL OF DAY\n10% OFF UPTO ₹40\nUSE STEALDEALAB...
# ...                                                   ...
# 140652  20% OFF UPTO ₹50\nUSE TRYNEWABOVE ₹149, FLAT ₹...
# 140653  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140654  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140655  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
# 140656  FLAT ₹120 OFF\nUSE AXIS120ABOVE ₹500, FLAT ₹50...
#
#                           Area Pure Veg  Location
# 0       LALA LAJPAT RAI MARKET       No    Abohar
# 1               Central Abohar       No    Abohar
# 2               Central Abohar      Yes    Abohar
# 3               Central Abohar      Yes    Abohar
# 4                Circular Road       No    Abohar
# ...                        ...      ...       ...
# 140652       Yavatmal Locality      Yes  Yavatmal
# 140653           Yavatmal City      Yes  Yavatmal
# 140654       Yavatmal Locality      Yes  Yavatmal
# 140655       Yavatmal Locality       No  Yavatmal
# 140656       Yavatmal Locality       No  Yavatmal
#
# [140657 rows x 10 columns]

# %%
df['Offer Name'] = df['Offer Name'].str.replace('\n', ',')

# %%
df
# Out:
#                      Restaurant Name                Cuisine Rating  \
# 0                    La Pino'Z Pizza         Pizzas, Pastas    4.0
# 1                    The Second Wife   Indian, North Indian    3.6
# 2                        Tasty Bites     Italian, Beverages    3.8
# 3                        Food Studio        Pizzas, Burgers    3.5
# 4                       Roll Express      Fast Food, Snacks    4.3
# ...                              ...                    ...    ...
# 140652             Yummy Momo'S Cafe     Chinese, Fast Food    4.6
# 140653              CAFE FIRST FLOOR      Beverages, Snacks    3.2
# 140654  Cafe Coffee Aani Barach Kahi                 Snacks    3.2
# 140655       Patil Family Restaurant  North Indian, Biryani    4.3
# 140656      Prabhakar Mama Cha Dhaba           North Indian     --
#
#        Number of Ratings  Average Price  Number of Offers  \
# 0                     10            250                 2
# 1                     50            250                 2
# 2                     10            200                 1
# 3                      8             49                 5
# 4                    100            200                 2
# ...                  ...            ...               ...
# 140652                 3            100                 3
# 140653                 3            200                 2
# 140654                50            150                 2
# 140655                 9            200                 2
# 140656                 0            350                 2
#
#                                                Offer Name  \
# 0       FLAT DEAL,FLAT ₹125 OFF,USE FLAT125ABOVE ₹699,...
# 1       30% OFF UPTO ₹75,USE TRYNEWABOVE ₹149, FLAT ₹1...
# 2                     FLAT ₹120 OFF,USE AXIS120ABOVE ₹500
# 3       50% OFF UPTO ₹100,USE TRYNEWABOVE ₹129, FLAT D...
# 4       DEAL OF DAY,10% OFF UPTO ₹40,USE STEALDEALABOV...
# ...                                                   ...
# 140652  20% OFF UPTO ₹50,USE TRYNEWABOVE ₹149, FLAT ₹1...
# 140653  FLAT ₹120 OFF,USE AXIS120ABOVE ₹500, FLAT ₹50 ...
# 140654  FLAT ₹120 OFF,USE AXIS120ABOVE ₹500, FLAT ₹50 ...
# 140655  FLAT ₹120 OFF,USE AXIS120ABOVE ₹500, FLAT ₹50 ...
# 140656  FLAT ₹120 OFF,USE AXIS120ABOVE ₹500, FLAT ₹50 ...
#
#                           Area Pure Veg  Location
# 0       LALA LAJPAT RAI MARKET       No    Abohar
# 1               Central Abohar       No    Abohar
# 2               Central Abohar      Yes    Abohar
# 3               Central Abohar      Yes    Abohar
# 4                Circular Road       No    Abohar
# ...                        ...      ...       ...
# 140652       Yavatmal Locality      Yes  Yavatmal
# 140653           Yavatmal City      Yes  Yavatmal
# 140654       Yavatmal Locality      Yes  Yavatmal
# 140655       Yavatmal Locality       No  Yavatmal
# 140656       Yavatmal Locality       No  Yavatmal
#
# [140657 rows x 10 columns]

# %% [markdown]
# <div style="padding: 20px;border-radius: 16px;background-color: #FF3CAC;
# background-image: linear-gradient(225deg, #FF3CAC 0%, #784BA0 50%, #2B86C5 100%);
# color: white;text-align:center;font-family: Inter,sans-serif;">
#         <h4 style="font-size: 24px;">Exploratory Data Analysis (EDA)</h4>
#     </div>

# %%
pure_veg_counts = df['Pure Veg'].value_counts().reset_index()
pure_veg_counts.columns = ['Pure Veg', 'Count']

# Plot a pie chart
fig = px.pie(
    pure_veg_counts,
    names='Pure Veg',
    values='Count',
    title='Distribution of Pure Vegetarian Restaurants',
    color_discrete_sequence=px.colors.qualitative.Set3,
    template='seaborn'
)

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2ac152dc-961d-499b-b65f-79fc924df616" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ac152dc-961d-499b-b65f-79fc924df616")) {                    Plotly.newPlot(                        "2ac152dc-961d-499b-b65f-79fc924df616",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Pure Veg=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["No","Yes"],"legendgroup":"","name":"","showlegend":true,"values":[81494,59163],"type":"pie"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,1 ...

# %%
import matplotlib.pyplot as plt

df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
df['Rating Category'] = df['Rating'].apply(lambda x: '0-3' if pd.isna(x) or x < 3 else ('3-4' if x < 4 else '4+'))
rating_counts = df['Rating Category'].value_counts()
colors = ['gold', 'lightcoral', 'lightskyblue']

plt.figure(figsize=(8, 8))
plt.pie(rating_counts, labels=rating_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribution of Ratings')
plt.show()

# %%
#After getting the unique prices, we can divide them into different categories
unique_prices = [50, 100, 150, 200, 250, 300, 500, 400, 350, 450, 40, 0, 550, 48, 1, 600, 32, 900, 750, 800, 650, 10, 12, 850, 2]

# Define the price ranges
price_ranges = {
    'Less than 50': lambda x: x < 50,
    '100-200': lambda x: 100 <= x < 200,
    '200-300': lambda x: 200 <= x < 300,
    '300-400': lambda x: 300 <= x < 400,
    '400-500': lambda x: 400 <= x < 500,
    '500-700': lambda x: 500 <= x < 700,
    'Greater than 700': lambda x: x > 700
}

# Count the occurrences in each price range
price_counts = {range_name: sum(price_range(price) for price in unique_prices) for range_name, price_range in price_ranges.items()}


labels = price_counts.keys()
sizes = price_counts.values()

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  

plt.title('Distribution of Average Prices')
plt.show()

# %%
#To find all possible Cuisine in the dataset
cuisine_column = df['Cuisine']

all_cuisines = [cuisine.split(', ') for cuisine in cuisine_column if pd.notna(cuisine)]
unique_cuisines = set([c for sublist in all_cuisines for c in sublist])

print("All Possible Cuisines:", unique_cuisines)
# Out:
# All Possible Cuisines: {'Juices', 'Maharashtrian', 'Singaporean', 'Pastas', 'Tibetan', 'Japanese', 'Cafe', 'Chettinad', 'African', 'Fast Food', 'Arabian', 'Tribal', 'To Avail This Use Code AZAD105', 'South Indian', 'Chaat', 'Keto', 'North indian', 'Italian', 'Cakes and Pastries', 'Awadhi', 'Sushi', 'fast food', 'Salads', 'Kashmiri', 'Haleem', 'Meat', 'Italian-American', 'Kebabs', 'Desserts', 'German', 'Seafood', 'Sweets', 'Street Food', 'Combo', 'Vietnamese', 'Grill', 'Pizzas', 'Rs.40 Off', 'Malwani', 'Naga', 'Coastal', 'Assamese', 'Burmese', 'Beverages', 'indian', 'South indian', 'Khasi', 'Steakhouse', 'Waffle', 'Oriya', 'Nepalese', 'Discount offer from Garden Cafe Express Kankurgachi', 'Default', 'Buffalo meat', 'Parsi', 'Andhra', 'Healthy Food', 'Goan', 'Rolls', 'Barbecue', 'Tex-Mex', 'Tandoor', 'Ice Cream', 'British', 'Paan', 'Bihari', 'American', 'SVANidhi Street Food Vendor', 'Kerala', 'Indonesian', 'Navratri Special', 'Malaysian', 'Lucknowi', 'French', 'snacks', 'Oriental', 'Greek', 'Portuguese', 'Snacks', 'Indian', 'Mongolian', 'Mughlai', 'North Indian', 'Asian', 'Thai', 'Ice Cream Cakes', 'Continental', 'Jain', 'Tandoor ', 'Persian', 'Punjabi', 'Burgers', 'Burger', 'Konkan', 'Pan-Asian', 'Rajasthani', 'Mexican', 'Special Discount from (The Scoop)', 'Mangalorean', 'Momos', 'Korean', 'Bubble Tea', 'burgers', 'Code valid on bill over Rs.500', 'chinese', 'Afghani', 'Bhutanese', 'Middle Eastern', 'North Eastern', 'Bengali', 'Mediterranean', 'Rolls & Wraps', 'Free Delivery ! Limited Stocks!', 'Gujarati', 'Sindhi', 'Bakery', 'Hyderabadi', 'Popular Brand Store', 'Spanish', 'Biryani', 'Home Food', 'Lebanese', 'Bangladeshi', 'Thalis', 'European', 'Turkish', 'North Indian,', 'Telangana', 'South American', 'Chinese', 'Rayalaseema'}

# %%
import pandas as pd
import plotly.express as px

cuisine_counts = df['Cuisine'].str.split(', ').explode().value_counts()
top_15_cuisines = cuisine_counts.head(15)
plot_data = pd.DataFrame({'Cuisine': top_15_cuisines.index, 'Frequency': top_15_cuisines.values})
colors = px.colors.qualitative.Set3

fig = px.bar(plot_data, x='Frequency', y='Cuisine', color='Cuisine',
             color_discrete_sequence=colors,
             orientation='h', labels={'Frequency': 'Frequency'},
             title='Top 15 Cuisines', width=800, height=500)

fig.update_layout(showlegend=False)  
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="79fe47bb-9649-4afe-af3e-a00f0bf343fa" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79fe47bb-9649-4afe-af3e-a00f0bf343fa")) {                    Plotly.newPlot(                        "79fe47bb-9649-4afe-af3e-a00f0bf343fa",                        [{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chinese","marker":{"color":"rgb(141,211,199)","pattern":{"shape":""}},"name":"Chinese","offsetgroup":"Chinese","orientation":"h","showlegend":true,"textposition":"auto","x":[37898],"xaxis":"x","y":["Chinese"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North Indian","marker":{"color":"rgb(255,255,179)","pattern":{"shape":""}},"name":"North Indian","offsetgroup":"North Indian","orientation":"h","showlegend":true,"textposition":"auto","x":[28966],"xaxis":"x","y":["North Indian"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Indian","marker":{"color":"rgb(190,186,218)","pattern":{"shape":""}},"name":"Indian","offsetgroup":"Indian","orientation":"h","showlegend":true,"textposition":"auto","x":[23374],"xaxis":"x","y":["Indian"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Snacks","marker":{"color":"rgb(251,128,114)","pattern":{"shape":""}},"name":"Snacks","offsetgroup":"Snacks","orientation":"h","showlegend":true,"textposition":"auto","x":[17468],"xaxis":"x","y":["Snacks"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Biryani","marker":{"color":"rgb(128,177,211)","pattern":{"shape":""}},"name":"Biryani","offsetgroup":"Biryani","orientation":"h","showlegend":true,"textposition":"auto","x":[15132],"xaxis":"x","y":["Biryani"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fast Food","marker":{"color":"rgb(253,180,98)","pattern":{"shape":""}},"name":"Fast Food","offsetgroup":"Fast Food","orientation":"h","showlegend":true,"textposition":"auto","x":[13504],"xaxis":"x","y":["Fast Food"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beverages","marker":{"color":"rgb(179,222,105)","pattern":{"shape":""}},"name":"Beverages","offsetgroup":"Beverages","orientation":"h","showlegend":true,"textposition":"auto","x":[13269],"xaxis":"x","y":["Beverages"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Indian","marker":{"color":"rgb(252,205,229)","pattern":{"shape":""}},"name":"South Indian","offsetgroup":"South Indian","orientation":"h","showlegend":true,"textposition":"auto","x":[12399],"xaxis":"x","y":["South Indian"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003cbr\u003eFrequency=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pizzas","marker":{"color":"rgb(217,217,217)","pattern":{"shape":""}},"name":"Pizzas","offsetgroup":"Pizzas","orientation":"h","showlegend":true,"textposition":"auto","x":[12200],"xaxis":"x","y":["Pizzas"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cuisine=%{y}\u003 ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

cuisine_text = ','.join(df['Cuisine'].dropna())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(cuisine_text)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

average_price = df['Average Price']
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# Define rating categories
def categorize_rating(rating):
    if rating < 3:
        return '<3'
    elif 3 <= rating < 4:
        return '3-4'
    else:
        return '4+'

df['Rating Category'] = df['Rating'].apply(categorize_rating)

# Define a color palette for each category
palette = {'<3': 'red', '3-4': 'orange', '4+': 'green'}

plt.figure(figsize=(10, 6))
sns.scatterplot(x=average_price, y=df['Rating'], hue=df['Rating Category'], palette=palette, alpha=0.7)
plt.title('Relation between Average Price and Rating')
plt.xlabel('Average Price')
plt.ylabel('Rating')
plt.legend(title='Rating Category')
plt.show()

# %%
import pandas as pd
import plotly.express as px
from geopy.geocoders import ArcGIS


df = df[df['Location'] != '-']
restaurant_count = df.groupby("Location")["Restaurant Name"].count().reset_index(name='count')

nom = ArcGIS()
restaurant_count[["Lat", "Long"]] = restaurant_count['Location'].apply(lambda x: nom.geocode(x)[1]).apply(pd.Series)

fig = px.scatter_mapbox(
    restaurant_count,
    lon='Long',
    lat='Lat',
    zoom=3,
    color='Location',
    size='count',
    title='Restaurant Distribution Across Locations',
    mapbox_style='open-street-map',
)

fig.update_layout(margin={"r": 0, 't': 50, 'l': 0, 'b': 10})
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <div>                            <div id="de0f1770-efc3-447f-a415-80731e479845" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de0f1770-efc3-447f-a415-80731e479845")) {                    Plotly.newPlot(                        "de0f1770-efc3-447f-a415-80731e479845",                        [{"hovertemplate":"Location=Abohar\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[30.14296],"legendgroup":"Abohar","lon":[74.19578],"marker":{"color":"#636efa","size":[51],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Abohar","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Adilabad\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[19.67203],"legendgroup":"Adilabad","lon":[78.5359],"marker":{"color":"#EF553B","size":[30],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Adilabad","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Adoni\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[15.62788],"legendgroup":"Adoni","lon":[77.27495],"marker":{"color":"#00cc96","size":[36],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Adoni","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Agra\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[27.19219],"legendgroup":"Agra","lon":[78.00005],"marker":{"color":"#ab63fa","size":[1132],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Agra","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Ahmedabad\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[23.02778],"legendgroup":"Ahmedabad","lon":[72.60026],"marker":{"color":"#FFA15A","size":[1801],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Ahmedabad","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Ahmednagar\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[19.09211],"legendgroup":"Ahmednagar","lon":[74.73842],"marker":{"color":"#19d3f3","size":[233],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Ahmednagar","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Aizawl\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[23.72894],"legendgroup":"Aizawl","lon":[92.71791],"marker":{"color":"#FF6692","size":[72],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Aizawl","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Ajmer\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[26.46554],"legendgroup":"Ajmer","lon":[74.63173],"marker":{"color":"#B6E880","size":[373],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Ajmer","showlegend":true,"subplot":"mapbox","type":"scattermapbox"},{"hovertemplate":"Location=Akola\u003cbr\u003ecount=%{marker.size}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[20.70535],"legendgroup":"Akola","lon":[77.00218],"marker":{"color":"#FF97FF","size":[141],"sizemode":"area","sizeref":6.0125},"mode":"markers","name":"Akola","showlegend":true,"subplot":"mapbox","type":"sc ...

# %%
import pandas as pd
import plotly.express as px
from geopy.geocoders import ArcGIS

# Assuming your data is in a DataFrame named 'df'
# Replace 'Location' with the actual column name from your dataset

# Filter out rows with '-' location (if applicable)
df = df[df['Location'] != '-']

# Group by Location and get the count of restaurants
restaurant_count = df.groupby("Location")["Restaurant Name"].count().reset_index(name='count')

# Geocode locations using ArcGIS
nom = ArcGIS()
restaurant_count[["Lat", "Long"]] = restaurant_count['Location'].apply(lambda x: nom.geocode(x)[1]).apply(pd.Series)

# Create a heatmap on Mapbox
fig = px.density_mapbox(
    restaurant_count.dropna(subset=['Lat', 'Long']),
    lat='Lat',
    lon='Long',
    z='count',
    radius=10,  # Adjust the radius as needed
    zoom=4,
    mapbox_style="carto-positron",  # You can try other mapbox styles
    title='Restaurant Heatmap in India',
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="d27abcc1-487a-475f-9f18-cf4394a1c050" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d27abcc1-487a-475f-9f18-cf4394a1c050")) {                    Plotly.newPlot(                        "d27abcc1-487a-475f-9f18-cf4394a1c050",                        [{"coloraxis":"coloraxis","hovertemplate":"count=%{z}\u003cbr\u003eLat=%{lat}\u003cbr\u003eLong=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[30.14296,19.67203,15.62788,27.19219,23.02778,19.09211,23.72894,26.46554,20.70535,9.5013,27.88636,26.51644,25.43609,29.59681,27.55619,18.72085,30.36099,23.13338,12.78791,20.93333,21.60517,31.63347,22.55251,14.68352,21.63526,13.08449,22.88333,26.13289,25.5582,23.6856,19.87016,28.1759,26.06832,30.93015,16.16623,26.69984,28.69381,27.57684,21.81664,20.7064,21.50096,15.14468,25.75835,25.74241,25.22099,25.47758,12.96614,12.89268,18.16525,25.09606,23.24073,21.1336,28.35441,25.46497,21.92386,25.75199,30.37451,18.2335,22.65756,26.79684,31.80921,30.20747,26.10119,18.98957,25.42442,25.9153,15.86704,24.10042,24.10042,26.80352,21.90316,25.39452,17.65121,21.06327,13.84846,25.24446,21.17119,26.92663,27.21087,21.69482,13.99363,21.77524,19.90585,21.22074,25.34707,16.54078,26.56707,28.21261,23.26466,20.26882,23.25397,21.04854,17.90802,25.20254,16.8282,29.3732,28.01649,22.0785,20.76957,26.73366,18.65457,10.00255,19.79777,23.66191,26.46936,23.04277,28.03643,28.40974,20.5399,25.43425,21.30868,25.57225,15.39932,22.54577,24.11987,20.46295,28.45688,30.7036,19.9665,13.08376,25.78194,24.90855,22.05697,11.39706,20.7588,13.55,13.32335,17.52385,14.22049,13.20604,24.88963,28.30415,10.99415,26.31962,11.74515,20.46653,19.97614,22.85562,24.04822,20.4252,26.15516,27.03937,31.81679,26.89966,14.4593,30.3097,24.89444,28.63409,24.48909,26.50249,22.96585,23.79596,22.59529,32.21666,10.73695,18.94365,15.45111,26.69286,20.90286,27.48439,27.38409,25.91174,20.71567,13.29452,27.35933,24.26838,23.84163,23.51583,16.71811,11.34065,27.57365,26.77615,26.77279,28.39262,30.65548,27.39134,27.02722,30.642163204,27.17326,30.40896,27.15211,30.92574,15.44303,16.23422,23.08333,26.47249,25.40521,27.33154,26.20694,24.78497,25.58333,24.18711,22.77547,16.16506,26.50722,27.13582,21.45879,26.46645,26.75432,16.43547,14.14746,24.64643,15.16042,16.29974,32.04088,28.47717,26.17723,26.22011,25.68544,22.06046,29.22254,22.50249,25.96085,15.33306,29.09591,29.58182,28.72985,27.39491,29.94791,13.00344,27.59551,14.79276,25.43217,29.15394,26.00316,22.74747,31.53723,15.26891,12.73647,15.35046,17.3949,16.69311,24.80756,22.71622,22.61477,23.17416,19.08533,30.80243,18.78827,25.21343,26.92591,31.33081,21.00292,19.84102,26.51667,32.70267,22.46961,24.92142,25.74508,24.58979,25.4486,22.44972,21.86528,28.12564,29.31577,28.60767,26.26694,26.76765,21.51966,14.46734,14.11197,29.79742,16.96036,17.33282,18.33272,22.95998,27.03157,11.87482,26.43562,8.09008,31.37775,17.27691,10.92549,10.07416,18.43915,29.69197,10.95921,14.81832,29.21399,25.53852,23.75129204,14.91288,9.16981,20.50612,21.63193,25.51095,26.77591,20.70687,17.25163,21.82122,30.70793,22.32834,26.10262,26.58164,9.93601,25.66288,26.40403,13.13768,16.70448,22.57059,8.88686,15.32956,22.3458,25.16531,29.74525,17.5433,9.00295,9.59476,9.17167,11.2588,12.52646,23.39062,31.904115999,10.95947,15.82551,29.97323,12.45739,27.94822,24.69129,18.39721,18.75275,26.85471,30.90726,16.18747,13.56445,26.96379,12.424,9.92418,16.74385,25.29164,27.22814,11.0429,25.01094,20.54966,30.20538,13.16871,18.99744337,16.86753,29.9596,30.66509,24.07259,12.52739,12.89785,13.35,23.42609,15.73587,27.49193,25.93854,11.10114,22.422,28.99862,23.60599,11.29351,16.86095,25.13432,28.83624,30.81892,28.83893,22.80779,26.49052,26.65164,24.59147,25.2819,31.95173,30.47506,18.94018,25.36556,30.45543,29.47046,26.157524875,12.30902,23.4103 ...
